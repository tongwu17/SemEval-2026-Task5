# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/finetune_bert_simple/
# Out:
# /content/drive/MyDrive/finetune_bert_simple

# %%
# !ls
# Out:
# convert_data.py      __pycache__		 run_param_search.py
# data		     README.md			 test_predictions.jsonl
# dataset.py	     requirements.txt		 top10_eval_acc_std.csv
# finetune-bert.ipynb  results			 top10_eval_spearman.csv
# model.py	     run_all.py			 train.py
# predict2.py	     run_complete_comparison.py  Untitled.ipynb

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Data preprocessing

# %%
# !python convert_data.py \
        --input data/test.json \
        --output data/test_converted.json
# Out:
# Loading data from data/test.json...
# Converted 930 samples
# Saving to data/test_converted.json...
#  Conversion complete!
#   Samples with ending: 620
#   Samples without ending: 310
#   Unique homonyms: 87

# %% [markdown]
# #Training (parameter search)

# %%
# !python run_param_search.py
# Out:
# 2026-02-16 17:46:45.560501: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-16 17:46:45.578067: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771264005.601256   45853 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771264005.608908   45853 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #Prediction

# %%
# !python predict.py \
  --experiment_dir results/parameter_search/model_deberta-large_bs8_ep10_lr1e-04_pool_mean_loss_mse_rw0.25_unc0_r8_a32 \
  --test_file data/test_converted.json \
  --output_file test_predictions.jsonl \
# Out:
# 2026-02-16 18:44:28.871798: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-16 18:44:28.890569: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771267468.913119   60868 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771267468.920579   60868 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
